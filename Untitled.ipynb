# %%
import scipy.sparse
from sagemaker import image_uris
image_uris.retrieve(framework='tensorflow',region='us-east-1',version='2.12.1',image_scope='inference',instance_type='ml.c5.4xlarge')
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml
# '763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.1-cpu'

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 520713654638.dkr.ecr.us-east-1.amazonaws.com

# %%
# !docker pull 520713654638.dkr.ecr.us-east-1.amazonaws.com/sagemaker-tensorflow-serving:1.12.0-cpu

# %%
import scipy.sparse
from sagemaker import image_uris
image_uris.retrieve(framework='tensorflow',region='us-east-1',version='2.12.0',image_scope='training',instance_type='ml.c5.4xlarge')

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-1.amazonaws.com

# %%
# !docker images

# %%
# !docker build -t 319840978863.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:mondo -f Dockerfile.train .

# %%
# !docker images

# %%
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator
import os

role=get_execution_role()

hyperparameters={'epochs': 1}

estimator=Estimator(
    image_uri='319840978863.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:mondo',
    role=role,
    instance_count=1,
    instance_type='local',
    hyperparameters=hyperparameters,
    output_path='file://{}/data/output'.format(os.getcwd())
)

print('##### ESTIMATOR FIT STARTED')
estimator.fit('file://{}/data/input/abalone.data'.format(os.getcwd()))
print('##### ESTIMATOR FIT COMPLETED')

# %%
# !tar -xzf data/output/output.tar.gz

# %%
# !tar -xzf ./data/output/model.tar.gz

# %%
# %%sh
# # Specify an image name
# image_name=tensorflow-training
# echo "image_name: ${image_name} ######################"
#
# account=$(aws sts get-caller-identity --query Account --output text)
# echo "account: ${account} ######################"
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# echo "region: ${region} ######################"
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image_name}:2.12.0-cpu-py310-pluto-2"
# echo "fullname: ${fullname} ######################"
#
# aws ecr describe-repositories --repository-names "${image_name}"
# if [ $? -ne 0 ]
# then
# aws ecr create-repository --repository-name "${image_name}"
# fi

# %%
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin  319840978863.dkr.ecr.us-east-1.amazonaws.com

# %%
# !docker images

# %%
# !docker tag ciao:mondo 319840978863.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:mondo

# %%
# !docker images

# %%
# !docker push 319840978863.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:mondo

# %%
from sagemaker import get_execution_role
from sagemaker.estimator import Estimator
import os

role=get_execution_role()

hyperparameters={'epochs': 1}

estimator=Estimator(
    image_uri='319840978863.dkr.ecr.us-east-1.amazonaws.com/tensorflow-training:mondo',
    role=role,
    instance_count=1,
    instance_type='ml.p2.xlarge',
    hyperparameters=hyperparameters,
    output_path='s3://itsar123-larocca/data/output/'
)

print('##### ESTIMATOR FIT STARTED')
estimator.fit('s3://itsar123-larocca/data/input/train.csv')
print('##### ESTIMATOR FIT COMPLETED')

# %%
# !tar -xzf model.tar.gz
# Out:
# tar: Ignoring unknown extended header keyword `LIBARCHIVE.creationtime'

# %%
# !pip install tensorflow keras
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.1 kB)
# Collecting keras
#   Downloading keras-3.6.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Downloading flatbuffers-24.3.25-py2.py3-none-any.whl.metadata (850 bytes)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Downloading gast-0.6.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt-einsum>=2.3.2 (from tensorflow)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting tensorboard<2.19,>=2.18 (from tensorflow)
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorflow) (3.12.1)
# Collecting ml-dtypes<0.5.0,>=0.4.0 (from tensorflow)
#   Downloading ml_dtypes-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: rich in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from keras) (13.9.3)
# Collecting namex (from keras)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras)
#   Downloading optree-0.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (47 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.19,>=2.18->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.0.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from packaging->tensorflow) (3.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Downloading tensorflow-2.18.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (615.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 615.3/615.3 MB 26.5 MB/s eta 0:00:0000:0100:01
# Downloading keras-3.6.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 5.7 MB/s eta 0:00:00
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# Downloading grpcio-1.67.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 20.4 MB/s eta 0:00:00:00:01
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 34.4 MB/s eta 0:00:00:00:0100:01
# Downloading ml_dtypes-0.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.2 MB/s eta 0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 18.4 MB/s eta 0:00:00ta 0:00:01
# Downloading tensorflow_io_gcs_filesystem-0.37.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 20.8 MB/s eta 0:00:00:00:01
# Downloading termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.13.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (358 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Installing collected packages: namex, libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, optree, opt-einsum, ml-dtypes, grpcio, gast, astunparse, absl-py, tensorboard, keras, tensorflow
# Successfully installed absl-py-2.1.0 astunparse-1.6.3 flatbuffers-24.3.25 gast-0.6.0 grpcio-1.67.1 keras-3.6.0 libclang-18.1.1 ml-dtypes-0.4.1 namex-0.0.8 opt-einsum-3.4.0 optree-0.13.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 tensorflow-2.18.0 tensorflow-io-gcs-filesystem-0.37.1 termcolor-2.5.0

# %%
# !pip freeze
# Out:
# absl-py==2.1.0
# aiohappyeyeballs @ file:///home/conda/feedstock_root/build_artifacts/aiohappyeyeballs_1727779797566/work
# aiohttp @ file:///home/conda/feedstock_root/build_artifacts/aiohttp_1728628981184/work
# aiosignal @ file:///home/conda/feedstock_root/build_artifacts/aiosignal_1667935791922/work
# alabaster @ file:///home/conda/feedstock_root/build_artifacts/alabaster_1722035799745/work
# alembic==1.13.3
# annotated-types==0.7.0
# anyio @ file:///home/conda/feedstock_root/build_artifacts/anyio_1728935693959/work
# argon2-cffi @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi_1692818318753/work
# argon2-cffi-bindings @ file:///home/conda/feedstock_root/build_artifacts/argon2-cffi-bindings_1725356557095/work
# arrow @ file:///home/conda/feedstock_root/build_artifacts/arrow_1696128962909/work
# astroid @ file:///home/conda/feedstock_root/build_artifacts/astroid_1728150398578/work
# astropy @ file:///home/conda/feedstock_root/build_artifacts/astropy_1727441840664/work
# astropy-iers-data @ file:///home/conda/feedstock_root/build_artifacts/astropy-iers-data_1728886348176/work
# asttokens @ file:///home/conda/feedstock_root/build_artifacts/asttokens_1698341106958/work
# astunparse==1.6.3
# async-lru @ file:///home/conda/feedstock_root/build_artifacts/async-lru_1690563019058/work
# async-timeout @ file:///home/conda/feedstock_root/build_artifacts/async-timeout_1691763562544/work
# asyncssh @ file:///home/conda/feedstock_root/build_artifacts/asyncssh_1725374799434/work
# atomicwrites @ file:///home/conda/feedstock_root/build_artifacts/atomicwrites_1657325823582/work
# attrs==23.2.0
# autopep8 @ file:///home/conda/feedstock_root/build_artifacts/autopep8_1693061251004/work
# autovizwidget @ file:///home/conda/feedstock_root/build_artifacts/autovizwidget_1695512335638/work
# awscli==1.35.17
# Babel @ file:///home/conda/feedstock_root/build_artifacts/babel_1702422572539/work
# backports.tarfile @ file:///home/conda/feedstock_root/build_artifacts/backports.tarfile_1712700614056/work
# beautifulsoup4 @ file:///home/conda/feedstock_root/build_artifacts/beautifulsoup4_1705564648255/work
# binaryornot==0.4.4
# bitarray @ file:///home/conda/feedstock_root/build_artifacts/bitarray_1729063587342/work
# black @ file:///home/conda/feedstock_root/build_artifacts/black-recipe_1728503747318/work
# bleach @ file:///home/conda/feedstock_root/build_artifacts/bleach_1696630167146/work
# blinker @ file:///home/conda/feedstock_root/build_artifacts/blinker_1715091184126/work
# bokeh @ file:///home/conda/feedstock_root/build_artifacts/bokeh_1728932480540/work
# boto3==1.35.51
# botocore==1.35.51
# Bottleneck @ file:///home/conda/feedstock_root/build_artifacts/bottleneck_1729268858017/work
# Brotli @ file:///home/conda/feedstock_root/build_artifacts/brotli-split_1725267488082/work
# brotlipy @ file:///home/conda/feedstock_root/build_artifacts/brotlipy_1725393311144/work
# cached-property @ file:///home/conda/feedstock_root/build_artifacts/cached_property_1615209429212/work
# cachetools==5.5.0
# certifi @ file:///home/conda/feedstock_root/build_artifacts/certifi_1725278078093/work/certifi
# cffi @ file:///home/conda/feedstock_root/build_artifacts/cffi_1725560520483/work
# chardet @ file:///home/conda/feedstock_root/build_artifacts/chardet_1724954770414/work
# charset-normalizer @ file:///home/conda/feedstock_root/build_artifacts/charset-normalizer_1728479282467/work
# click @ file:///home/conda/feedstock_root/build_artifacts/click_1692311806742/work
# cloudpickle==2.2.1
# colorama @ file:///home/conda/feedstock_root/build_artifacts/colorama_1666700638685/work
# comm @ file:///home/conda/feedstock_root/build_artifacts/comm_1710320294760/work
# contourpy @ file:///home/conda/feedstock_root/build_artifacts/contourpy_1727293539542/work
# cookiecutter @ file:///home/conda/feedstock_root/build_artifacts/cookiecutter_1708608886262/work
# coverage @ file:///home/conda/feedstock_root/build_artifacts/coverage_1729610035939/work
# cryptography @ file:///home/conda/feedstock_root/build_artifacts/cryptography-split_1729286669947/work
# cycler @ file:///home/conda/feedstock_root/build_artifacts/cycler_1696677705766/work
# Cython @ file:///home/conda/feedstock_root/build_artifacts/cython_1727455855473/work
# cytoolz @ file:///home/conda/feedstock_root/build_artifacts/cytoolz_1728335001300/work
# dask @ file:///home/conda/feedstock_root/build_artifacts/dask-core_1714636356238/work
# databricks-sdk==0.36.0
# debugpy @ file:///home/conda/feedstock_root/build_artifacts/debugpy_1728594113125/work
# decorator @ file:///home/conda/feedstock_root/build_artifacts/decorator_1641555617451/work
# defusedxml @ file:///home/conda/feedstock_root/build_artifacts/defusedxml_1615232257335/work
# Deprecated @ file:///home/conda/feedstock_root/build_artifacts/deprecated_1685233314779/work
# diff-match-patch @ file:///home/conda/feedstock_root/build_artifacts/diff-match-patch_1683670697993/work
# dill @ file:///home/conda/feedstock_root/build_artifacts/dill_1727594984357/work
# distributed @ file:///home/conda/feedstock_root/build_artifacts/distributed_1708967079660/work
# docker==7.1.0
# docstring-to-markdown @ file:///home/conda/feedstock_root/build_artifacts/docstring-to-markdown_1708563025188/work
# docutils==0.16
# dparse==0.6.3
# entrypoints @ file:///home/conda/feedstock_root/build_artifacts/entrypoints_1643888246732/work
# et-xmlfile @ file:///home/conda/feedstock_root/build_artifacts/et_xmlfile_1674664118162/work
# exceptiongroup @ file:///home/conda/feedstock_root/build_artifacts/exceptiongroup_1720869315914/work
# executing @ file:///home/conda/feedstock_root/build_artifacts/executing_1725214404607/work
# fastcache @ file:///home/conda/feedstock_root/build_artifacts/fastcache_1725746788488/work
# fastjsonschema @ file:///home/conda/feedstock_root/build_artifacts/python-fastjsonschema_1718477020893/work/dist
# filelock @ file:///home/conda/feedstock_root/build_artifacts/filelock_1726613473834/work
# flake8 @ file:///home/conda/feedstock_root/build_artifacts/flake8_1722878870427/work
# Flask @ file:///home/conda/feedstock_root/build_artifacts/flask_1712667726126/work
# Flask-Cors @ file:///home/conda/feedstock_root/build_artifacts/flask-cors_1725086079197/work
# flatbuffers==24.3.25
# fonttools @ file:///home/conda/feedstock_root/build_artifacts/fonttools_1729530309088/work
# fqdn @ file:///home/conda/feedstock_root/build_artifacts/fqdn_1638810296540/work/dist
# frozenlist @ file:///home/conda/feedstock_root/build_artifacts/frozenlist_1725395670451/work
# fsspec @ file:///home/conda/feedstock_root/build_artifacts/fsspec_1729608855534/work
# future @ file:///home/conda/feedstock_root/build_artifacts/future_1708610096684/work
# gast==0.6.0
# gevent @ file:///home/conda/feedstock_root/build_artifacts/gevent_1696750251337/work
# gitdb==4.0.11
# GitPython==3.1.43
# gmpy2 @ file:///home/conda/feedstock_root/build_artifacts/gmpy2_1725379788616/work
# google-auth==2.35.0
# google-pasta==0.2.0
# graphene==3.4.1
# graphql-core==3.2.5
# graphql-relay==3.2.0
# greenlet @ file:///home/conda/feedstock_root/build_artifacts/greenlet_1726922182064/work
# grpcio==1.67.1
# gssapi @ file:///home/conda/feedstock_root/build_artifacts/python-gssapi_1727961835352/work
# gunicorn==23.0.0
# h11 @ file:///home/conda/feedstock_root/build_artifacts/h11_1664132893548/work
# h2 @ file:///home/conda/feedstock_root/build_artifacts/h2_1634280454336/work
# h5py @ file:///home/conda/feedstock_root/build_artifacts/h5py_1729617641689/work
# hdijupyterutils @ file:///home/conda/feedstock_root/build_artifacts/hdijupyterutils_1695512275947/work
# hpack==4.0.0
# httpcore @ file:///home/conda/feedstock_root/build_artifacts/httpcore_1727820890233/work
# httpx @ file:///home/conda/feedstock_root/build_artifacts/httpx_1724778349782/work
# hyperframe @ file:///home/conda/feedstock_root/build_artifacts/hyperframe_1619110129307/work
# idna @ file:///home/conda/feedstock_root/build_artifacts/idna_1726459485162/work
# imagecodecs @ file:///home/conda/feedstock_root/build_artifacts/imagecodecs_1729174764072/work
# imageio @ file:///home/conda/feedstock_root/build_artifacts/imageio_1729190692267/work
# imagesize @ file:///home/conda/feedstock_root/build_artifacts/imagesize_1656939531508/work
# immutables @ file:///home/conda/feedstock_root/build_artifacts/immutables_1728557212296/work
# importlib-metadata==6.11.0
# importlib_resources @ file:///home/conda/feedstock_root/build_artifacts/importlib_resources_1725921340658/work
# inflection @ file:///home/conda/feedstock_root/build_artifacts/inflection_1598089801258/work
# iniconfig @ file:///home/conda/feedstock_root/build_artifacts/iniconfig_1673103042956/work
# intervaltree @ file:///home/conda/feedstock_root/build_artifacts/intervaltree_1683532206518/work
# ipykernel @ file:///home/conda/feedstock_root/build_artifacts/ipykernel_1719845459717/work
# ipython @ file:///home/conda/feedstock_root/build_artifacts/ipython_1727944696411/work
# ipywidgets @ file:///home/conda/feedstock_root/build_artifacts/ipywidgets_1724334859652/work
# isoduration @ file:///home/conda/feedstock_root/build_artifacts/isoduration_1638811571363/work/dist
# isort @ file:///home/conda/feedstock_root/build_artifacts/isort_1702518492027/work
# itsdangerous @ file:///home/conda/feedstock_root/build_artifacts/itsdangerous_1713372668944/work
# jaraco.classes @ file:///home/conda/feedstock_root/build_artifacts/jaraco.classes_1713939306738/work
# jaraco.context @ file:///home/conda/feedstock_root/build_artifacts/jaraco.context_1714372187587/work
# jaraco.functools @ file:///home/conda/feedstock_root/build_artifacts/jaraco.functools_1701695162614/work
# jedi @ file:///home/conda/feedstock_root/build_artifacts/jedi_1696326070614/work
# jeepney @ file:///home/conda/feedstock_root/build_artifacts/jeepney_1649085214306/work
# jellyfish @ file:///home/conda/feedstock_root/build_artifacts/jellyfish_1725658944863/work
# Jinja2 @ file:///home/conda/feedstock_root/build_artifacts/jinja2_1715127149914/work
# jmespath @ file:///home/conda/feedstock_root/build_artifacts/jmespath_1655568249366/work
# joblib @ file:///home/conda/feedstock_root/build_artifacts/joblib_1714665484399/work
# json5 @ file:///home/conda/feedstock_root/build_artifacts/json5_1712986206667/work
# jsonpointer @ file:///home/conda/feedstock_root/build_artifacts/jsonpointer_1725302897999/work
# jsonschema @ file:///home/conda/feedstock_root/build_artifacts/jsonschema_1720529478715/work
# jsonschema-specifications @ file:///tmp/tmpvslgxhz5/src
# jupyter @ file:///home/conda/feedstock_root/build_artifacts/jupyter_1725037521377/work
# jupyter-console @ file:///home/conda/feedstock_root/build_artifacts/jupyter_console_1678118109161/work
# jupyter-events @ file:///home/conda/feedstock_root/build_artifacts/jupyter_events_1710805637316/work
# jupyter-lsp @ file:///home/conda/feedstock_root/build_artifacts/jupyter-lsp-meta_1712707420468/work/jupyter-lsp
# jupyter_client @ file:///home/conda/feedstock_root/build_artifacts/jupyter_client_1726610684920/work
# jupyter_core @ file:///home/conda/feedstock_root/build_artifacts/jupyter_core_1727163409502/work
# jupyter_server @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_1720816649297/work
# jupyter_server_terminals @ file:///home/conda/feedstock_root/build_artifacts/jupyter_server_terminals_1710262634903/work
# jupyterlab @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_1724745148804/work
# jupyterlab_pygments @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_pygments_1707149102966/work
# jupyterlab_server @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_server-split_1721163288448/work
# jupyterlab_widgets @ file:///home/conda/feedstock_root/build_artifacts/jupyterlab_widgets_1724331334887/work
# keras==3.6.0
# keyring @ file:///home/conda/feedstock_root/build_artifacts/keyring_1726970992756/work
# kiwisolver @ file:///home/conda/feedstock_root/build_artifacts/kiwisolver_1725459213453/work
# krb5 @ file:///home/conda/feedstock_root/build_artifacts/pykrb5_1708557570437/work
# lazy-object-proxy @ file:///home/conda/feedstock_root/build_artifacts/lazy-object-proxy_1702663550721/work
# lazy_loader @ file:///home/conda/feedstock_root/build_artifacts/lazy-loader_1723774329602/work
# libclang==18.1.1
# lief @ file:///home/conda/feedstock_root/build_artifacts/lief_1726040283347/work/api/python
# llvmlite==0.43.0
# locket @ file:///home/conda/feedstock_root/build_artifacts/locket_1650660393415/work
# lz4 @ file:///home/conda/feedstock_root/build_artifacts/lz4_1725089426044/work
# Mako==1.3.6
# Markdown==3.7
# markdown-it-py @ file:///home/conda/feedstock_root/build_artifacts/markdown-it-py_1686175045316/work
# MarkupSafe @ file:///home/conda/feedstock_root/build_artifacts/markupsafe_1729351299924/work
# matplotlib==3.9.2
# matplotlib-inline @ file:///home/conda/feedstock_root/build_artifacts/matplotlib-inline_1713250518406/work
# mccabe @ file:///home/conda/feedstock_root/build_artifacts/mccabe_1643049622439/work
# mdurl @ file:///home/conda/feedstock_root/build_artifacts/mdurl_1704317613764/work
# mistune @ file:///home/conda/feedstock_root/build_artifacts/mistune_1698947099619/work
# mkl-service==2.4.1
# mkl_fft==1.3.10
# ml-dtypes==0.4.1
# mlflow==2.17.1
# mlflow-skinny==2.17.1
# mock==4.0.3
# more-itertools @ file:///home/conda/feedstock_root/build_artifacts/more-itertools_1725630081114/work
# mpmath @ file:///home/conda/feedstock_root/build_artifacts/mpmath_1678228039184/work
# msgpack @ file:///home/conda/feedstock_root/build_artifacts/msgpack-python_1725974993022/work
# multidict @ file:///home/conda/feedstock_root/build_artifacts/multidict_1729065475820/work
# multiprocess==0.70.17
# munkres==1.1.4
# mypy-extensions @ file:///home/conda/feedstock_root/build_artifacts/mypy_extensions_1675543315189/work
# namex==0.0.8
# nbclient @ file:///home/conda/feedstock_root/build_artifacts/nbclient_1710317608672/work
# nbconvert @ file:///home/conda/feedstock_root/build_artifacts/nbconvert-meta_1718135430380/work
# nbformat @ file:///home/conda/feedstock_root/build_artifacts/nbformat_1712238998817/work
# nest_asyncio @ file:///home/conda/feedstock_root/build_artifacts/nest-asyncio_1705850609492/work
# networkx @ file:///home/conda/feedstock_root/build_artifacts/networkx_1728631323331/work
# nltk @ file:///home/conda/feedstock_root/build_artifacts/nltk_1724022741962/work
# notebook @ file:///home/conda/feedstock_root/build_artifacts/notebook_1724861303656/work
# notebook_shim @ file:///home/conda/feedstock_root/build_artifacts/notebook-shim_1707957777232/work
# numba @ file:///home/conda/feedstock_root/build_artifacts/numba_1718888013454/work
# numexpr @ file:///home/conda/feedstock_root/build_artifacts/numexpr_1728902482900/work
# numpy @ file:///home/conda/feedstock_root/build_artifacts/numpy_1707225380409/work/dist/numpy-1.26.4-cp310-cp310-linux_x86_64.whl#sha256=51131fd8fc130cd168aecaf1bc0ea85f92e8ffebf211772ceb16ac2e7f10d7ca
# numpydoc @ file:///home/conda/feedstock_root/build_artifacts/numpydoc_1723472227761/work
# openpyxl @ file:///home/conda/feedstock_root/build_artifacts/openpyxl_1725460826776/work
# opentelemetry-api==1.27.0
# opentelemetry-sdk==1.27.0
# opentelemetry-semantic-conventions==0.48b0
# opt_einsum==3.4.0
# optree==0.13.0
# overrides @ file:///home/conda/feedstock_root/build_artifacts/overrides_1706394519472/work
# packaging==21.3
# pandas==1.5.3
# pandocfilters @ file:///home/conda/feedstock_root/build_artifacts/pandocfilters_1631603243851/work
# parso @ file:///home/conda/feedstock_root/build_artifacts/parso_1712320355065/work
# partd @ file:///home/conda/feedstock_root/build_artifacts/partd_1715026491486/work
# path @ file:///home/conda/feedstock_root/build_artifacts/path_1722709938802/work
# pathlib2 @ file:///home/conda/feedstock_root/build_artifacts/pathlib2_1725350144616/work
# pathos==0.3.3
# pathspec @ file:///home/conda/feedstock_root/build_artifacts/pathspec_1702249949303/work
# patsy @ file:///home/conda/feedstock_root/build_artifacts/patsy_1704469236901/work
# pexpect @ file:///home/conda/feedstock_root/build_artifacts/pexpect_1706113125309/work
# pickleshare @ file:///home/conda/feedstock_root/build_artifacts/pickleshare_1602536217715/work
# pillow @ file:///home/conda/feedstock_root/build_artifacts/pillow_1729065631911/work
# pkginfo @ file:///home/conda/feedstock_root/build_artifacts/pkginfo_1728616516923/work
# pkgutil_resolve_name @ file:///home/conda/feedstock_root/build_artifacts/pkgutil-resolve-name_1694617248815/work
# platformdirs @ file:///home/conda/feedstock_root/build_artifacts/platformdirs_1726613481435/work
# plotly @ file:///home/conda/feedstock_root/build_artifacts/plotly_1726179518483/work
# pluggy @ file:///home/conda/feedstock_root/build_artifacts/pluggy_1713667077545/work
# ply @ file:///home/conda/feedstock_root/build_artifacts/ply_1712242996588/work
# pox==0.3.5
# ppft==1.7.6.9
# prometheus_client @ file:///home/conda/feedstock_root/build_artifacts/prometheus_client_1726901976720/work
# prompt_toolkit @ file:///home/conda/feedstock_root/build_artifacts/prompt-toolkit_1727341649933/work
# propcache @ file:///home/conda/feedstock_root/build_artifacts/propcache_1728545722056/work
# protobuf==4.25.5
# psutil @ file:///home/conda/feedstock_root/build_artifacts/psutil_1728965169125/work
# psycopg2 @ file:///home/conda/feedstock_root/build_artifacts/psycopg2-split_1727869826152/work
# psycopg2-binary @ file:///home/conda/feedstock_root/build_artifacts/psycopg2-split_1701737547976/work/psycopg2-binary
# ptyprocess @ file:///home/conda/feedstock_root/build_artifacts/ptyprocess_1609419310487/work/dist/ptyprocess-0.7.0-py2.py3-none-any.whl
# pure_eval @ file:///home/conda/feedstock_root/build_artifacts/pure_eval_1721585709575/work
# py-cpuinfo @ file:///home/conda/feedstock_root/build_artifacts/py-cpuinfo_1666774466606/work
# py4j==0.10.9.5
# pyarrow==17.0.0
# pyarrow-hotfix @ file:///home/conda/feedstock_root/build_artifacts/pyarrow-hotfix_1700596371886/work
# pyasn1==0.6.1
# pyasn1_modules==0.4.1
# pycodestyle @ file:///home/conda/feedstock_root/build_artifacts/pycodestyle_1722846760694/work
# pyconify @ file:///home/conda/feedstock_root/build_artifacts/pyconify_1698110940903/work
# pycosat @ file:///home/conda/feedstock_root/build_artifacts/pycosat_1696355758174/work
# pycparser @ file:///home/conda/feedstock_root/build_artifacts/pycparser_1711811537435/work
# pycryptodome @ file:///home/conda/feedstock_root/build_artifacts/pycryptodome_1727030789984/work
# pycurl @ file:///home/conda/feedstock_root/build_artifacts/pycurl_1725361426969/work
# pydantic==2.9.2
# pydantic_core==2.23.4
# pydocstyle @ file:///home/conda/feedstock_root/build_artifacts/pydocstyle_1673997487070/work
# pyerfa @ file:///home/conda/feedstock_root/build_artifacts/pyerfa_1725532146957/work
# pyflakes @ file:///home/conda/feedstock_root/build_artifacts/pyflakes_1704424584912/work
# PyGithub @ file:///home/conda/feedstock_root/build_artifacts/pygithub_1724668538857/work
# Pygments @ file:///home/conda/feedstock_root/build_artifacts/pygments_1714846767233/work
# PyJWT @ file:///home/conda/feedstock_root/build_artifacts/pyjwt_1722701264352/work
# pykerberos @ file:///home/conda/feedstock_root/build_artifacts/pykerberos_1725289118206/work
# pylint @ file:///home/conda/feedstock_root/build_artifacts/pylint_1727266422285/work
# pylint-venv @ file:///home/conda/feedstock_root/build_artifacts/pylint-venv_1698219336631/work
# pyls-spyder @ file:///home/conda/feedstock_root/build_artifacts/pyls-spyder_1619747398504/work
# PyNaCl @ file:///home/conda/feedstock_root/build_artifacts/pynacl_1725739248276/work
# pynvml @ file:///home/conda/feedstock_root/build_artifacts/pynvml_1721161061587/work
# pyodbc @ file:///home/conda/feedstock_root/build_artifacts/pyodbc_1729084271546/work
# pyOpenSSL @ file:///home/conda/feedstock_root/build_artifacts/pyopenssl_1722587090966/work
# pyparsing @ file:///home/conda/feedstock_root/build_artifacts/pyparsing_1728880423364/work
# PyQt5==5.15.9
# PyQt5-sip==12.12.2
# PyQtWebEngine==5.15.4
# pyrsistent @ file:///home/conda/feedstock_root/build_artifacts/pyrsistent_1725353509161/work
# PySide6==6.7.3
# PySocks @ file:///home/conda/feedstock_root/build_artifacts/pysocks_1661604839144/work
# pyspark==3.3.0
# pyspnego @ file:///home/conda/feedstock_root/build_artifacts/pyspnego_1721810735206/work
# pytest @ file:///home/conda/feedstock_root/build_artifacts/pytest_1725977232342/work
# python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/python-dateutil_1709299778482/work
# python-json-logger @ file:///home/conda/feedstock_root/build_artifacts/python-json-logger_1677079630776/work
# python-lsp-black @ file:///home/conda/feedstock_root/build_artifacts/python-lsp-black_1702956932456/work
# python-lsp-jsonrpc @ file:///home/conda/feedstock_root/build_artifacts/python-lsp-jsonrpc_1695528365348/work
# python-lsp-server @ file:///home/conda/feedstock_root/build_artifacts/python-lsp-server-meta_1724636813752/work
# python-slugify @ file:///home/conda/feedstock_root/build_artifacts/python-slugify-split_1707425621764/work
# pytoolconfig @ file:///home/conda/feedstock_root/build_artifacts/pytoolconfig_1675124745143/work
# pytz @ file:///home/conda/feedstock_root/build_artifacts/pytz_1726055524169/work
# pyuca==1.2
# PyWavelets==1.7.0
# pyxdg @ file:///home/conda/feedstock_root/build_artifacts/pyxdg_1654536799286/work
# PyYAML @ file:///home/conda/feedstock_root/build_artifacts/pyyaml_1725456145900/work
# pyzmq @ file:///home/conda/feedstock_root/build_artifacts/pyzmq_1728642224099/work
# QDarkStyle @ file:///home/conda/feedstock_root/build_artifacts/qdarkstyle_1702957860620/work
# qstylizer @ file:///home/conda/feedstock_root/build_artifacts/qstylizer_1713394158018/work/dist/qstylizer-0.2.3-py2.py3-none-any.whl#sha256=9f7b5d720ea5b7459972f570e09067f8286e9d00955e2b91ef2bd4d0b5edce1c
# QtAwesome @ file:///home/conda/feedstock_root/build_artifacts/qtawesome_1711652164228/work
# qtconsole @ file:///home/conda/feedstock_root/build_artifacts/qtconsole-base_1724884130933/work
# QtPy @ file:///home/conda/feedstock_root/build_artifacts/qtpy_1698112029416/work
# referencing @ file:///home/conda/feedstock_root/build_artifacts/referencing_1714619483868/work
# regex @ file:///home/conda/feedstock_root/build_artifacts/regex_1726095592943/work
# requests @ file:///home/conda/feedstock_root/build_artifacts/requests_1717057054362/work
# requests-kerberos @ file:///home/conda/feedstock_root/build_artifacts/requests-kerberos_1726948606045/work
# rfc3339-validator @ file:///home/conda/feedstock_root/build_artifacts/rfc3339-validator_1638811747357/work
# rfc3986-validator @ file:///home/conda/feedstock_root/build_artifacts/rfc3986-validator_1598024191506/work
# rich @ file:///home/conda/feedstock_root/build_artifacts/rich_1729622917073/work/dist
# rope @ file:///home/conda/feedstock_root/build_artifacts/rope_1711296293824/work
# rpds-py @ file:///home/conda/feedstock_root/build_artifacts/rpds-py_1725327046348/work
# rsa==4.7.2
# Rtree @ file:///home/conda/feedstock_root/build_artifacts/rtree_1725321009255/work
# ruamel-yaml-conda @ file:///home/conda/feedstock_root/build_artifacts/ruamel_yaml_1695546328261/work
# ruamel.yaml @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml_1728765002497/work
# ruamel.yaml.clib @ file:///home/conda/feedstock_root/build_artifacts/ruamel.yaml.clib_1728724455198/work
# s3fs==0.4.2
# s3transfer @ file:///home/conda/feedstock_root/build_artifacts/s3transfer_1728459792363/work
# sagemaker==2.233.0
# sagemaker-core==1.0.10
# sagemaker-mlflow==0.1.0
# sagemaker_pyspark==1.4.5
# schema==0.7.7
# scikit-image @ file:///home/conda/feedstock_root/build_artifacts/scikit-image_1723842187328/work/dist/scikit_image-0.24.0-cp310-cp310-linux_x86_64.whl#sha256=630bc214d3adb1567feebb9dfd74b1ee8976f1469b95c283f4ff5444d825b850
# scikit-learn @ file:///home/conda/feedstock_root/build_artifacts/scikit-learn_1726082665124/work/dist/scikit_learn-1.5.2-cp310-cp310-linux_x86_64.whl#sha256=914b88d7388a0d1dbe92050e4583e162038cff9d8bf6b85d76a4d58ac89079d0
# scipy @ file:///home/conda/feedstock_root/build_artifacts/scipy-split_1729480705456/work/dist/scipy-1.14.1-cp310-cp310-linux_x86_64.whl#sha256=031f36ca64aae0336618344467acc89ac97b2470d780485ef621e9b41b26e9bf
# seaborn @ file:///home/conda/feedstock_root/build_artifacts/seaborn-split_1714494649443/work
# SecretStorage @ file:///home/conda/feedstock_root/build_artifacts/secretstorage_1725915608929/work
# Send2Trash @ file:///home/conda/feedstock_root/build_artifacts/send2trash_1712584999685/work
# shap @ file:///home/conda/feedstock_root/build_artifacts/shap_1715196928513/work
# shiboken6==6.7.3
# sip @ file:///home/conda/feedstock_root/build_artifacts/sip_1697300428978/work
# six @ file:///home/conda/feedstock_root/build_artifacts/six_1620240208055/work
# slicer @ file:///home/conda/feedstock_root/build_artifacts/slicer_1710029110974/work
# smdebug-rulesconfig==1.0.1
# smmap==5.0.1
# sniffio @ file:///home/conda/feedstock_root/build_artifacts/sniffio_1708952932303/work
# snowballstemmer @ file:///home/conda/feedstock_root/build_artifacts/snowballstemmer_1637143057757/work
# sortedcontainers @ file:///home/conda/feedstock_root/build_artifacts/sortedcontainers_1621217038088/work
# soupsieve @ file:///home/conda/feedstock_root/build_artifacts/soupsieve_1693929250441/work
# sparkmagic @ file:///home/conda/feedstock_root/build_artifacts/sparkmagic_1695511119398/work/sparkmagic
# Sphinx @ file:///home/conda/feedstock_root/build_artifacts/sphinx_1728873985511/work
# sphinxcontrib-applehelp @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-applehelp_1722244468291/work
# sphinxcontrib-devhelp @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-devhelp_1722245025182/work
# sphinxcontrib-htmlhelp @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-htmlhelp_1722248302725/work
# sphinxcontrib-jsmath @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-jsmath_1691604704163/work
# sphinxcontrib-qthelp @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-qthelp_1722245860247/work
# sphinxcontrib-serializinghtml @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-serializinghtml_1705118225549/work
# sphinxcontrib-websupport @ file:///home/conda/feedstock_root/build_artifacts/sphinxcontrib-websupport_1705125899521/work
# spyder @ file:///home/conda/feedstock_root/build_artifacts/spyder_1727838385670/work
# spyder-kernels @ file:///home/conda/feedstock_root/build_artifacts/spyder-kernels_1724950643893/work
# SQLAlchemy @ file:///home/conda/feedstock_root/build_artifacts/sqlalchemy_1729066348927/work
# sqlparse==0.5.1
# stack-data @ file:///home/conda/feedstock_root/build_artifacts/stack_data_1669632077133/work
# statsmodels @ file:///home/conda/feedstock_root/build_artifacts/statsmodels_1727986707121/work
# superqt @ file:///home/conda/feedstock_root/build_artifacts/superqt_1717810401439/work
# sympy @ file:///home/conda/feedstock_root/build_artifacts/sympy_1728484478345/work
# tables @ file:///home/conda/feedstock_root/build_artifacts/pytables_1724161053447/work
# tabulate @ file:///home/conda/feedstock_root/build_artifacts/tabulate_1665138452165/work
# tblib @ file:///home/conda/feedstock_root/build_artifacts/tblib_1702066284995/work
# tenacity @ file:///home/conda/feedstock_root/build_artifacts/tenacity_1722278858289/work
# tensorboard==2.18.0
# tensorboard-data-server==0.7.2
# tensorflow==2.18.0
# tensorflow-io-gcs-filesystem==0.37.1
# termcolor==2.5.0
# terminado @ file:///home/conda/feedstock_root/build_artifacts/terminado_1710262609923/work
# testpath @ file:///home/conda/feedstock_root/build_artifacts/testpath_1645693042223/work
# text-unidecode @ file:///home/conda/feedstock_root/build_artifacts/text-unidecode_1694707102786/work
# textdistance @ file:///home/conda/feedstock_root/build_artifacts/textdistance_1721228410193/work
# threadpoolctl @ file:///home/conda/feedstock_root/build_artifacts/threadpoolctl_1714400101435/work
# three-merge @ file:///home/conda/feedstock_root/build_artifacts/three-merge_1595515817927/work
# tifffile @ file:///home/conda/feedstock_root/build_artifacts/tifffile_1727250434425/work
# tinycss2 @ file:///home/conda/feedstock_root/build_artifacts/tinycss2_1713974937325/work
# toml @ file:///home/conda/feedstock_root/build_artifacts/toml_1604308577558/work
# tomli @ file:///home/conda/feedstock_root/build_artifacts/tomli_1727974628237/work
# tomlkit @ file:///home/conda/feedstock_root/build_artifacts/tomlkit_1723631480657/work
# toolz @ file:///home/conda/feedstock_root/build_artifacts/toolz_1728059506884/work
# tornado @ file:///home/conda/feedstock_root/build_artifacts/tornado_1724960687225/work
# tqdm @ file:///home/conda/feedstock_root/build_artifacts/tqdm_1722737464726/work
# traitlets @ file:///home/conda/feedstock_root/build_artifacts/traitlets_1713535121073/work
# typed-ast @ file:///home/conda/feedstock_root/build_artifacts/typed-ast_1695409894288/work
# types-python-dateutil @ file:///home/conda/feedstock_root/build_artifacts/types-python-dateutil_1727940235703/work
# typing-utils @ file:///home/conda/feedstock_root/build_artifacts/typing_utils_1622899189314/work
# typing_extensions @ file:///home/conda/feedstock_root/build_artifacts/typing_extensions_1717802530399/work
# ujson @ file:///home/conda/feedstock_root/build_artifacts/ujson_1724954402136/work
# unicodedata2 @ file:///home/conda/feedstock_root/build_artifacts/unicodedata2_1695847980273/work
# uri-template @ file:///home/conda/feedstock_root/build_artifacts/uri-template_1688655812972/work/dist
# urllib3 @ file:///home/conda/feedstock_root/build_artifacts/urllib3_1726496430923/work
# watchdog @ file:///home/conda/feedstock_root/build_artifacts/watchdog_1727641329159/work
# wcwidth @ file:///home/conda/feedstock_root/build_artifacts/wcwidth_1704731205417/work
# webcolors @ file:///home/conda/feedstock_root/build_artifacts/webcolors_1723294704277/work
# webencodings @ file:///home/conda/feedstock_root/build_artifacts/webencodings_1694681268211/work
# websocket-client @ file:///home/conda/feedstock_root/build_artifacts/websocket-client_1713923384721/work
# Werkzeug @ file:///home/conda/feedstock_root/build_artifacts/werkzeug_1724330738730/work
# whatthepatch @ file:///home/conda/feedstock_root/build_artifacts/whatthepatch_1720999218266/work
# widgetsnbextension @ file:///home/conda/feedstock_root/build_artifacts/widgetsnbextension_1724331337528/work
# wrapt @ file:///home/conda/feedstock_root/build_artifacts/wrapt_1724957893583/work
# wurlitzer @ file:///home/conda/feedstock_root/build_artifacts/wurlitzer_1718203955352/work
# XlsxWriter @ file:///home/conda/feedstock_root/build_artifacts/xlsxwriter_1723277104680/work
# xyzservices @ file:///home/conda/feedstock_root/build_artifacts/xyzservices_1725366347586/work
# yapf @ file:///home/conda/feedstock_root/build_artifacts/yapf_1690387939953/work
# yarl @ file:///home/conda/feedstock_root/build_artifacts/yarl_1729423523125/work
# zict @ file:///home/conda/feedstock_root/build_artifacts/zict_1681770155528/work
# zipp @ file:///home/conda/feedstock_root/build_artifacts/zipp_1726248574750/work
# zope.event @ file:///home/conda/feedstock_root/build_artifacts/zope.event_1687705558811/work
# zope.interface @ file:///home/conda/feedstock_root/build_artifacts/zope.interface_1728568698519/work
# zstandard==0.23.0

# %%
from keras import models
model = models.load_model("abalone_model.keras")
# Out:
# 2024-11-05 13:13:50.870601: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1730812430.893223   21240 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1730812430.900208   21240 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-05 13:13:50.924144: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-05 13:14:13.522508: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
from keras import models
import numpy as np
import json

model = models.load_model("abalone_model.keras")
type(model)

predict_input = np.array([[0.475,0.37,0.125,0.5095,0.2165,0.1125,0.165,9]])
predict_result = model.predict(predict_input)

json.dumps({"predict_result": predict_result.tolist()})
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# '{"predict_result": [[0.0]]}'

# %%
# !pip install flask
# Out:
# Requirement already satisfied: flask in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (3.0.3)
# Requirement already satisfied: Werkzeug>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (3.0.4)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from flask) (1.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages (from Jinja2>=3.1.2->flask) (3.0.2)

# %%
# %%sh
# # Specify an image name
# image_name=tensorflow-inference
# echo "image_name: ${image_name} ######################"
#
# account=$(aws sts get-caller-identity --query Account --output text)
# echo "account: ${account} ######################"
#
# # Get the region defined in the current configuration (default to us-west-2 if none defined)
# region=$(aws configure get region)
# echo "region: ${region} ######################"
#
# fullname="${account}.dkr.ecr.${region}.amazonaws.com/${image_name}:2.12.0-cpu-py310-pluto-2"
# echo "fullname: ${fullname} ######################"
#
# aws ecr describe-repositories --repository-names "${image_name}"
# if [ $? -ne 0 ]
# then
# aws ecr create-repository --repository-name "${image_name}"
# fi
# Out:
# image_name: tensorflow-inference ######################
# account: 648633553332 ######################
# region: us-east-1 ######################
# fullname: 648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:2.12.0-cpu-py310-pluto-2 ######################
# An error occurred (RepositoryNotFoundException) when calling the DescribeRepositories operation: The repository with name 'tensorflow-inference' does not exist in the registry with id '648633553332'
# {
#     "repository": {
#         "repositoryArn": "arn:aws:ecr:us-east-1:648633553332:repository/tensorflow-inference",
#         "registryId": "648633553332",
#         "repositoryName": "tensorflow-inference",
#         "repositoryUri": "648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference",
#         "createdAt": 1730815814.296,
#         "imageTagMutability": "MUTABLE",
#         "imageScanningConfiguration": {
#             "scanOnPush": false
#         },
#         "encryptionConfiguration": {
#             "encryptionType": "AES256"
#         }
#     }
# }

# %%
#Dominio dell'immagine base, quindi è uguale per tutti
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 763104351884.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
#Codice build è univoco per persona
# !docker build -t 648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:mondo -f Dockerfile.inference .
# Out:
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.2s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
# [+] Building 0.3s (2/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
# [+] Building 0.4s (3/3)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
# [+] Building 0.5s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.1s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba018245 0B / 208.76MB  0.1s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa 0B / 28.58MB  0.1s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8c 0B / 342B  0.1s
# [+] Building 0.6s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.2s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba01 1.05MB / 208.76MB  0.2s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7 9.44MB / 28.58MB  0.2s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c9fbd6 0B / 72.61MB  0.2s
# [+] Building 0.8s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.4s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba01 5.24MB / 208.76MB  0.4s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 17.83MB / 28.58MB  0.4s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c9 7.34MB / 72.61MB  0.4s
# [+] Building 0.9s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.5s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba01 8.39MB / 208.76MB  0.5s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 22.02MB / 28.58MB  0.5s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 11.53MB / 72.61MB  0.5s
# [+] Building 1.1s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.7s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 14.68MB / 208.76MB  0.7s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 20.97MB / 72.61MB  0.7s
# [+] Building 1.2s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.9s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 20.97MB / 208.76MB  0.8s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 24.12MB / 72.61MB  0.8s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56c841 0B / 5.51MB  0.8s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.0s
# [+] Building 1.3s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.0s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 27.05MB / 208.76MB  0.9s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 28.31MB / 72.61MB  0.9s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 1.05MB / 5.51MB  0.9s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.1s
# [+] Building 1.4s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.1s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 30.41MB / 208.76MB  1.1s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 32.51MB / 72.61MB  1.1s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 3.15MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.2s
# [+] Building 1.6s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.2s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 35.65MB / 208.76MB  1.2s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 36.70MB / 72.61MB  1.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.3s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba702ddd 0B / 35.25MB  1.2s
# [+] Building 1.7s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.3s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 40.89MB / 208.76MB  1.3s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 39.85MB / 72.61MB  1.3s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.4s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba70 1.05MB / 35.25MB  1.3s
# [+] Building 1.8s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.4s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 49.28MB / 208.76MB  1.4s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 47.19MB / 72.61MB  1.4s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.6s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba70 7.34MB / 35.25MB  1.4s
# [+] Building 1.9s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.5s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 53.48MB / 208.76MB  1.5s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 51.38MB / 72.61MB  1.5s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.7s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 10.49MB / 35.25MB  1.5s
# [+] Building 2.0s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.6s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 58.72MB / 208.76MB  1.6s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 54.53MB / 72.61MB  1.6s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.8s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 12.58MB / 35.25MB  1.6s
# [+] Building 2.1s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.7s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 63.96MB / 208.76MB  1.7s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 57.67MB / 72.61MB  1.7s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  0.9s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 14.68MB / 35.25MB  1.7s
# [+] Building 2.2s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  1.9s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 67.11MB / 208.76MB  1.8s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 61.87MB / 72.61MB  1.8s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 17.83MB / 35.25MB  1.8s
# [+] Building 2.3s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.0s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 71.30MB / 208.76MB  1.9s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 66.06MB / 72.61MB  1.9s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.1s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 19.92MB / 35.25MB  1.9s
# [+] Building 2.5s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.1s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 80.74MB / 208.76MB  2.1s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.1s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.3s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 26.21MB / 35.25MB  2.1s
# [+] Building 2.7s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.3s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 87.03MB / 208.76MB  2.3s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.3s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.4s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 30.41MB / 35.25MB  2.3s
# [+] Building 2.8s (5/9)                                          docker:default
#  => [internal] load build definition from Dockerfile.inference             0.0s
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.4s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba0 93.32MB / 208.76MB  2.4s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.5s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.4s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.4s
# [+] Building 2.9s (5/9)                                          docker:default
#  => => transferring dockerfile: 265B                                       0.0s
#  => [internal] load metadata for 763104351884.dkr.ecr.us-east-1.amazonaws  0.3s
#  => [auth] sharing credentials for 763104351884.dkr.ecr.us-east-1.amazona  0.0s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.5s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 112.20MB / 208.76MB  2.5s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.7s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa823 2.10MB / 109.11MB  2.5s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb217 0B / 279B  2.5s
# [+] Building 3.1s (5/9)                                          docker:default
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.7s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 125.83MB / 208.76MB  2.7s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  1.9s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 10.49MB / 109.11MB  2.7s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d208 0B / 1.13MB  2.7s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
# [+] Building 3.2s (5/9)                                          docker:default
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  2.8s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 131.07MB / 208.76MB  2.8s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 14.62MB / 109.11MB  2.8s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d208 0B / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
# [+] Building 3.4s (5/9)                                          docker:default
#  => [internal] load build context                                          0.0s
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.0s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 138.41MB / 208.76MB  3.0s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 17.83MB / 109.11MB  3.0s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f9 0B / 4.96kB  3.0s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
# [+] Building 3.5s (5/9)                                          docker:default
#  => => transferring context: 79B                                           0.0s
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.1s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 149.95MB / 208.76MB  3.1s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 25.17MB / 109.11MB  3.1s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11 4.96kB / 4.96kB  2.9s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
#  => => sha256:6db276b52c22e28c6049da1cffe05b155dd29627948 1.05MB / 3.72MB  3.1s
# [+] Building 3.7s (5/9)                                          docker:default
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.3s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 160.43MB / 208.76MB  3.3s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 33.55MB / 109.11MB  3.3s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11 4.96kB / 4.96kB  2.9s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
#  => => sha256:6db276b52c22e28c6049da1cffe05b155dd29627948 3.72MB / 3.72MB  3.2s
#  => => sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c1 0B / 8.99MB  3.3s
# [+] Building 3.9s (5/9)                                          docker:default
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.5s
#  => => resolve 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  0.0s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 167.77MB / 208.76MB  3.5s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 42.99MB / 109.11MB  3.5s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11 4.96kB / 4.96kB  2.9s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
#  => => sha256:6db276b52c22e28c6049da1cffe05b155dd29627948 3.72MB / 3.72MB  3.2s
#  => => sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d6 6.29MB / 8.99MB  3.5s
# [+] Building 4.0s (5/9)                                          docker:default
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.6s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 171.97MB / 208.76MB  3.6s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 47.19MB / 109.11MB  3.6s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11 4.96kB / 4.96kB  2.9s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
#  => => sha256:6db276b52c22e28c6049da1cffe05b155dd29627948 3.72MB / 3.72MB  3.2s
#  => => sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d6 8.99MB / 8.99MB  3.6s
#  => => sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26 0B / 16.93kB  3.6s
# [+] Building 4.2s (5/9)                                          docker:default
#  => [1/4] FROM 763104351884.dkr.ecr.us-east-1.amazonaws.com/tensorflow-in  3.8s
#  => => sha256:b02640eda26a58fded218cb7bd7a5e1e54d81feacb4 5.14kB / 5.14kB  0.0s
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 184.55MB / 208.76MB  3.8s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 54.53MB / 109.11MB  3.8s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
#  => => sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466 3.50kB / 3.50kB  2.7s
#  => => sha256:3c7607a09603f23baa24943337f12dc904e531c0c11 4.96kB / 4.96kB  2.9s
#  => => extracting sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c8  0.0s
#  => => sha256:6db276b52c22e28c6049da1cffe05b155dd29627948 3.72MB / 3.72MB  3.2s
#  => => sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d6 8.99MB / 8.99MB  3.6s
#  => => sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26 0B / 16.93kB  3.8s
# [+] Building 4.4s (5/9)                                          docker:default
#  => => sha256:8d5daddf21edd05edc7beaf05933f3505d485ba 197.13MB / 208.76MB  4.0s
#  => => sha256:4d18a9b9a9249a881fb8ace501b8a63ceac1a8c3c 23.23kB / 23.23kB  0.0s
#  => => sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e 28.58MB / 28.58MB  0.7s
#  => => sha256:97f0c13e96887eef228594bfd90570f5d0ab98658edf53c 342B / 342B  0.1s
#  => => sha256:c80de5516dbc57bab6e7b5b47dd6af321cc1cd79c 72.61MB / 72.61MB  2.2s
#  => => sha256:74bf7ecc4a24f085465f33bb1efb7b48adecdd72c56 5.51MB / 5.51MB  1.1s
#  => => extracting sha256:99803d4b97f3db529ae9ca4174b0951afac6b309e7deaa8e  2.0s
#  => => sha256:007e08f7ff3e0c6a6ffe0554b4eef2f8f5b54fba7 35.25MB / 35.25MB  2.3s
#  => => sha256:deb09d4f4284c93d412f9105c155571469f0cd63e221a42 213B / 213B  2.3s
#  => => sha256:438dca95920fcb52ba88968bbf293d49c8ac6479b7703b8 129B / 129B  2.4s
#  => => sha256:b779862c22bb8b3b422b3d0eab203ca4d592aa82 62.91MB / 109.11MB  4.0s
#  => => sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb2 279B / 279B  2.5s
#  => => sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e6 3.50kB / 3.50kB  2.6s
#  => => sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535 1.13MB / 1.13MB  2.8s
# ...
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.2s
#  => => # Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 658.5 kB/s e
#  => => # ta 0:00:00
#  => => # Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 947.8 kB/s e
#  => => # ta 0:00:00
# [+] Building 71.6s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.3s
#  => => # ta 0:00:00
#  => => # Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 947.8 kB/s e
#  => => # ta 0:00:00
#  => => # Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
#  => => # Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
# [+] Building 71.7s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.5s
#  => => # Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 947.8 kB/s e
#  => => # ta 0:00:00
#  => => # Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
#  => => # Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
#  => => # Downloading click-8.1.7-py3-none-any.whl (97 kB)
# [+] Building 71.8s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.6s
#  => => # ta 0:00:00
#  => => # Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
#  => => # Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
#  => => # Downloading click-8.1.7-py3-none-any.whl (97 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 649.7 kB/s et
#  => => # a 0:00:00
# [+] Building 72.0s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.7s
#  => => # Downloading blinker-1.8.2-py3-none-any.whl (9.5 kB)
#  => => # Downloading click-8.1.7-py3-none-any.whl (97 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 649.7 kB/s et
#  => => # a 0:00:00
#  => => # Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
#  => => # Downloading gast-0.6.0-py3-none-any.whl (21 kB)
# [+] Building 72.1s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        17.9s
#  => => # Downloading click-8.1.7-py3-none-any.whl (97 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 649.7 kB/s et
#  => => # a 0:00:00
#  => => # Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
#  => => # Downloading gast-0.6.0-py3-none-any.whl (21 kB)
#  => => # Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# [+] Building 72.3s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        18.0s
#  => => # a 0:00:00
#  => => # Downloading flatbuffers-24.3.25-py2.py3-none-any.whl (26 kB)
#  => => # Downloading gast-0.6.0-py3-none-any.whl (21 kB)
#  => => # Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 365.3 kB/s et
#  => => # a 0:00:00
# [+] Building 72.4s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        18.2s
#  => => # Downloading gast-0.6.0-py3-none-any.whl (21 kB)
#  => => # Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 365.3 kB/s et
#  => => # a 0:00:00
#  => => # Downloading h5py-3.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux201
#  => => # 4_x86_64.whl (5.3 MB)
# [+] Building 72.5s (7/9)                                         docker:default
#  => => extracting sha256:966ffe74715b21ae891781525b86d317735b49ba62a8cb21  0.0s
#  => => extracting sha256:2bff5527db14a8bcc3081ffaf21566129f44cbc58e605807  0.0s
#  => => extracting sha256:d4e644cbd53cd69d6d202bff301a1af2b25aa6a7466ad60e  0.0s
#  => => extracting sha256:83d3c64ff86af3ba891c54bd6078660a4030f4f2535d2088  0.1s
#  => => extracting sha256:3c7607a09603f23baa24943337f12dc904e531c0c11d7f95  0.0s
#  => => extracting sha256:6db276b52c22e28c6049da1cffe05b155dd2962794886439  0.1s
#  => => extracting sha256:947f9857aafe2e8bcde7873ad734ef98ec7e3f657d681c16  0.4s
#  => => extracting sha256:af7fb51f1fc24000975713cb9c1b0f2a6c2b753fbbbf26aa  0.0s
#  => => extracting sha256:cbfd796fc40405c7c172fa1886be5dfeb4dd54126d11bf9a  0.0s
#  => => extracting sha256:767bee65519be2c48cb20be9a16e928b7c53f07284dd54f1  0.0s
#  => => extracting sha256:cbb85fa951d00ec843547a6431f9843bf853ce49f49dbccf  0.0s
#  => => extracting sha256:a1528748df6ef5f6b88aa994c3db5e1159b554c4d4621ee5  0.0s
#  => => extracting sha256:565b4750c043e82ea6395c10f2fb04a40b980ec93ebc162f  5.5s
#  => => extracting sha256:fec330abc7080f16ae6a3259cb7d1eaf66b2b6bef3223bfb  0.0s
#  => [2/4] ADD ./requirements.inference.txt /opt/requirements.txt           3.7s
#  => [3/4] RUN pip3 install -r/opt/requirements.txt                        18.3s
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 365.3 kB/s et
#  => => # a 0:00:00
#  => => # Downloading h5py-3.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux201
#  => => # 4_x86_64.whl (5.3 MB)
#  => => #    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 20.8 MB/s eta 0
#  => => # :00:00

# %%
# !docker images
# Out:
# REPOSITORY                                                          TAG       IMAGE ID       CREATED       SIZE
# 648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference   mondo     6c4e927c7041   5 years ago   377MB

# %%
# !docker push 648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:mondo
# Out:
# The push refers to repository [648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference]
#
# ab352ca1: Preparing
# 1bba5efb: Preparing
# bcb4634f: Preparing
# ebf683ff: Preparing
# 9781a77c: Preparing
# 13a20bf2: Preparing
# cdf4e497: Preparing
# 3f9454c0: Preparing
# no basic auth credentials

# %%
#Dominio dell'immagine base, quindi è uguale per tutti
# !aws ecr get-login-password --region us-east-1 | docker login --username AWS --password-stdin 648633553332.dkr.ecr.us-east-1.amazonaws.com
# Out:
# WARNING! Your password will be stored unencrypted in /home/ec2-user/.docker/config.json.
# Configure a credential helper to remove this warning. See
# https://docs.docker.com/engine/reference/commandline/login/#credentials-store
#
# Login Succeeded

# %%
# !docker push 648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference:mondo
# Out:
# The push refers to repository [648633553332.dkr.ecr.us-east-1.amazonaws.com/tensorflow-inference]
#
# ab352ca1: Preparing
# 1bba5efb: Preparing
# bcb4634f: Preparing
# ebf683ff: Preparing
# 9781a77c: Preparing
# 13a20bf2: Preparing
# cdf4e497: Preparing
# 3f9454c0: Preparing
# 6b5893dc: Pushed   126.2MB/122.2MBmondo: digest: sha256:2741292c10cfa163e6ba91c0e83100bb8debeac8a2213666b12f1f2560df7d12 size: 2203
